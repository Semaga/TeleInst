# %%
from instagram import Account, Media, WebAgent, Location
import os
from urllib.request import urlretrieve
import glob

import matplotlib.pyplot as plt 
# %matplotlib nbagg

# %%
names = ["al.semakin", 
         "zuck", 
         "travel__my_soul",
         "v_adikk",
         "kaiskhakova",
         "almaz_nasybullin",
         "_quitehour_",
         "annmorozko",
         "niyazeoh",
         "airatphd",
         "pilebokafilm"]
# names = []

# %%
agent = WebAgent()
account = Account("al.semakin")
agent.update(account)
# Out:
# {'biography': '24 y.o.\nKazan, Russia🇷🇺\nKazan Federal University\nInstitute of Physics⚛\nНемного о моих маленьких путешествиях',
#  'blocked_by_viewer': False,
#  'restricted_by_viewer': None,
#  'country_block': False,
#  'external_url': 'http://tlgg.ru/semakin_al',
#  'external_url_linkshimmed': 'https://l.instagram.com/?u=http%3A%2F%2Ftlgg.ru%2Fsemakin_al&e=ATPf4ZtdZ5veB6Am_eO7-Je_FTDZvvdah-6mDvq0bRml0VrTnYB0qXIl_pekSZlMQuPkuN6pEIMh7L1M&s=1',
#  'edge_followed_by': {'count': 567},
#  'followed_by_viewer': False,
#  'edge_follow': {'count': 562},
#  'follows_viewer': False,
#  'full_name': 'Aleksei Semakin',
#  'has_ar_effects': False,
#  'has_channel': False,
#  'has_blocked_viewer': False,
#  'highlight_reel_count': 5,
#  'has_requested_viewer': False,
#  'id': '424699962',
#  'is_business_account': False,
#  'is_joined_recently': False,
#  'business_category_name': None,
#  'overall_category_name': None,
#  'category_enum': None,
#  'is_private': False,
# ...

# %%
count = account.media_count
medias, pointers = agent.get_media(account, count = count)

# %%
type(medias[2])
# Out:
# instagram.entities.Media

# %%
likes_men, po = agent.get_likes(medias[0])

# %%
likes_men
# Out:
# [andrey.brylov,
#  _seli.k_,
#  californiajam,
#  stasyguz_psy,
#  nino_rmalno,
#  good_obuv_men,
#  mops.tayson,
#  kat__saz,
#  miheev_photorelax,
#  karina.muurrrf,
#  tanya29_97,
#  lera_vsolo,
#  kursovye.diplomy1,
#  nazmut13,
#  danil.zamanov,
#  vishna_foto,
#  itsmekamillla,
#  _dasmiss_,
#  safoneeva_y,
#  gii6iig]

# %%
location = Location(422336073)
agent.get_media(location)
# Out:
# ([CBs2ldtgCT5,
#   CBs2byzAdH6,
#   CBs2acrgSP_,
#   CBs2N8ehhYZ,
#   CBs19qQAn41,
#   CBs1qtwAmAa,
#   CBs08mbFyFb,
#   CBs0lVlqllB,
#   CBsz6ZkKHKp,
#   CBszqknA1rI,
#   CBszIbcAXoH,
#   CBsy9zQg08p],
#  '2336445982162112839')

# %%
location
# Out:
# 4132822

# %%
def getPhotoLocation(location):
    """
    Take location
    """
    agent = WebAgent()
    medias, point = agent.get_media(location)
    for i, media in enumerate(medias):
        print(f"{i} - {media.display_url}")

# %%
getPhotoLocation(location)
# Out:
# 0 - https://scontent-hel2-1.cdninstagram.com/v/t51.2885-15/e35/p1080x1080/104339573_273215484021167_4293057857709205633_n.jpg?_nc_ht=scontent-hel2-1.cdninstagram.com&_nc_cat=111&_nc_ohc=-42IIcabN7MAX-eSAf_&oh=ffe262a1423856b88c42b6ec73c1063a&oe=5F19D724
# 1 - https://scontent-hel2-1.cdninstagram.com/v/t51.2885-15/e35/p1080x1080/104181592_773283506540951_7470365843900536710_n.jpg?_nc_ht=scontent-hel2-1.cdninstagram.com&_nc_cat=111&_nc_ohc=ej2TOIjsO2EAX8e81y2&oh=0102b59d92e994aa69779ca3fc154b27&oe=5F18641C
# 2 - https://scontent-hel2-1.cdninstagram.com/v/t51.2885-15/e35/104321039_312235766840083_3729485882445451848_n.jpg?_nc_ht=scontent-hel2-1.cdninstagram.com&_nc_cat=107&_nc_ohc=-p8iaNuMGU8AX8nZrZs&oh=12d9f6a9c002bd2ac4ed709db9e0d61a&oe=5EF19E52
# 3 - https://instagram.fhel6-1.fna.fbcdn.net/v/t51.2885-15/e35/104141490_555552495117590_4428767559771646325_n.jpg?_nc_ht=instagram.fhel6-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=URMaSYyTJPwAX-ZQPz9&oh=8249a7cf2a6c03da683cbd391094ca4a&oe=5F18C810
# ...

# %%
# Out:
#   File "<ipython-input-44-f9090a9873aa>", line 1
#     instagram.
#               ^
# SyntaxError: invalid syntax
